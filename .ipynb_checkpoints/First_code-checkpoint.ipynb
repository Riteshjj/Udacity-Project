# %%
import pandas as pd

df_listing = pd.read_csv('./listings.csv')
df_reviews = pd.read_csv('./reviews.csv')
df_cal = pd.read_csv('./calendar.csv')

# %% [markdown]
# <h3 id='q1'>Question 1</h3>
#
# **1.** Provide the number of rows and columns in this dataset.

# %%
num_row_listing = str(df_listing.shape[0])
num_cols_listing = str(df_listing.shape[1])

print('number of rows in listing file: '+num_row_listing)
print('number of columns in listing file: '+num_cols_listing)
# Out:
# number of rows in listing file: 3585
# number of columns in listing file: 95

# %% [markdown]
# <h3 id='q1'>Question 2</h3>
#
# **1.** list integer column and drop empty columns

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_int_listing = df_listing.select_dtypes(include=numerics).dropna(axis=1, how='all', inplace=False)
df_int_listing
# Out:
#             id       scrape_id   host_id  host_listings_count  \
# 0     12147973  20160906204935  31303940                    1
# 1      3075044  20160906204935   2572247                    1
# 2         6976  20160906204935     16701                    1
# 3      1436513  20160906204935   6031442                    1
# 4      7651065  20160906204935  15396970                    1
# ...        ...             ...       ...                  ...
# 3580   8373729  20160906204935  19246369                   28
# 3581  14844274  20160906204935  37366454                    2
# 3582  14585486  20160906204935  11311919                    1
# 3583  14603878  20160906204935  74318064                    4
# 3584  14504422  20160906204935  42070843                   14
#
#       host_total_listings_count   latitude  longitude  accommodates  \
# 0                             1  42.282619 -71.133068             4
# 1                             1  42.286241 -71.134374             2
# ...
